# %%
# D:\Github\Machine_to_DeepingLearning\Competition\恶意样本检测\features
import pefile

pe = pefile.PE('./data/write/Backdoor.Win32.Bifrose.fmv_0e2c.exe')
#print(pe.OPTIONAL_HEADER)
#print(pe.OPTIONAL_HEADER.DATA_DIRECTORY[6].Size)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

black_data = './data/black/'
black_dataset_path = './data/black_data.csv'
write_data = './data/write/'
write_dataset_path = './data/write_data.csv'
    
black_dataset = pd.read_csv(black_dataset_path)
print('black_dataset Files Statistics')
black_dataset.describe()
# Out:
# black_dataset Files Statistics
#        DebugSize  DebugRVA  ImageVersion  OSVersion  ExportRVA  ExportSize  \
# count       10.0      10.0     10.000000       10.0       10.0        10.0
# mean         0.0       0.0      0.400000        4.0        0.0         0.0
# std          0.0       0.0      0.516398        0.0        0.0         0.0
# min          0.0       0.0      0.000000        4.0        0.0         0.0
# 25%          0.0       0.0      0.000000        4.0        0.0         0.0
# 50%          0.0       0.0      0.000000        4.0        0.0         0.0
# 75%          0.0       0.0      1.000000        4.0        0.0         0.0
# max          0.0       0.0      1.000000        4.0        0.0         0.0
#
#             IATRVA       ResSize  LinkerVersion  NumberOfSections  \
# count    10.000000     10.000000      10.000000         10.000000
# mean   2048.000000  14197.900000      18.700000          4.900000
# ...

# %%
write_dataset = pd.read_csv(write_dataset_path)
print('write_dataset Files Statistics')
write_dataset.describe()
# Out:
# write_dataset Files Statistics
#        DebugSize      DebugRVA  ImageVersion  OSVersion    ExportRVA  \
# count  13.000000  1.300000e+01     13.000000  13.000000    13.000000
# mean    4.384615  2.064920e+07      1.230769   4.538462   966.153846
# std    15.510956  7.445051e+07      2.862221   1.664101  1837.093803
# min     0.000000  0.000000e+00      0.000000   4.000000     0.000000
# 25%     0.000000  0.000000e+00      0.000000   4.000000     0.000000
# 50%     0.000000  0.000000e+00      0.000000   4.000000     0.000000
# 75%     0.000000  0.000000e+00      1.000000   4.000000     0.000000
# max    56.000000  2.684355e+08     10.000000  10.000000  4368.000000
#
#         ExportSize         IATRVA        ResSize  LinkerVersion  \
# count    13.000000      13.000000      13.000000      13.000000
# mean    707.846154   15796.307692   70950.230769       6.307692
# std    1623.119725   35811.608787  210748.249239       2.250356
# ...

# %%
black_dataset['clean'] = 0
write_dataset['clean'] = 1
import seaborn
# %matplotlib inline
fig,ax = plt.subplots()
x = black_dataset['IATRVA']
y = black_dataset['clean']
ax.scatter(x,y,color='r',label='black_dataset')
x1 = write_dataset['IATRVA']
y1 = write_dataset['clean']
ax.scatter(x1,y1,color='b',label='write_dataset')
ax.legend(loc="right")

# %%
# %matplotlib inline
fig,ax = plt.subplots()
x = black_dataset['DebugRVA']
y = black_dataset['clean']
ax.scatter(x,y,color='r',label='black_dataset')
x1 = write_dataset['DebugRVA']
y1 = write_dataset['clean']
ax.scatter(x1,y1,color='b',label='write_dataset')
ax.legend(loc="right")

# %%
# %matplotlib inline
fig,ax = plt.subplots()
x = black_dataset['ExportSize']
y = black_dataset['clean']
ax.scatter(x,y,color='r',label='black_dataset')
x1 = write_dataset['ExportSize']
y1 = write_dataset['clean']
ax.scatter(x1,y1,color='b',label='write_dataset')
ax.legend(loc="right")

# %%
import pandas as pd
dataset = pd.read_csv('malware-dataset.csv')
"""
Add this points dataset holds our data
Great let's split it into train/test and fix a random seed to keep our predictions constant
"""
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
#let's import 4 algorithms we would like to test
#neural networks
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
#random forests
from sklearn.ensemble import RandomForestClassifier
"""
Let's prepare our data
"""
state = np.random.randint(100)
X = dataset.drop('clean',axis = 1)
y = dataset['clean']
X = np.asarray(X)
y = np.asarray(y)
X = X[:,1:]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.1,random_state=0)
