# %% [markdown]
# # 参考来源
# 数据集：链接： https://pan.baidu.com/s/1KVRkkRp-E-W0tS4Q9qU7Ag 提取码：a9wl
#
# https://blog.51cto.com/u_15088375/3249422

# %% [markdown]
# # 1.导入数据包

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

df_data = pd.read_csv('./heart.csv')
df_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# # 2.简单统计

# %%
df_data.iloc[0, 0]
# Out:
# 63

# %%
type(df_data.iloc[0, 0]) is str
# Out:
# False

# %%
type(df_data.iloc[0, 0]) is np.type('int64')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-0518460687c3> in <module>
# ----> 1 type(df_data.iloc[0, 0]) is np.type('int64')
#
# AttributeError: module 'numpy' has no attribute 'type'

# %%
df_data.iloc[0, 0:1].dtypes is np.dtype('int64')
# Out:
# False

# %%
df_data.target.value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
df_data.isna().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %% [markdown]
# # 3.缺失值填充

# %%
df_data = df_data.fillna(0)  # 补全为0 的影响不会很大，除了类似于线性回归的迭代类型模型

# %% [markdown]
# # 4.切分数据集

# %%
features_name = [columns_name for columns_name in df_data.columns if columns_name not in ['target']]

# %% [markdown]
# # 5.独热化

# %%
pd.get_dummies(df_data)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# # 6.标准化
# 标准化的流程简单来说可以表达为:将数据按其属性(按列进行)减去其均值，然后除以其方差。最后得到的结果是，对每个属性/每列来说所有数据都聚集在0附近，方差值为1。

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split # 数据划分

print(df_data[features_name].shape)
stdScaler = StandardScaler()
X = stdScaler.fit_transform(df_data[features_name])
X_train_scaler,X_test_scaler,y_train_scaler,y_test_scaler = train_test_split(X,df_data['target'],test_size=0.3, random_state=0) 
X.shape
# Out:
# (303, 13)
# (303, 13)

# %% [markdown]
# # 7.非标准化

# %%
X_train,X_test,y_train,y_test = train_test_split(df_data[features_name],df_data['target'],test_size=0.3, random_state=0) 
y_test_scaler.value_counts()
# Out:
# 1    47
# 0    44
# Name: target, dtype: int64

# %%
X_train_scaler.shape
# Out:
# (212, 13)

# %% [markdown]
# # 8.训练模型
# ## 8.1 LR模型

# %%
from sklearn.linear_model import LogisticRegression
# 标准化
clf = LogisticRegression().fit(X_train_scaler, y_train_scaler)
clf.score(X_test_scaler, y_test_scaler)
# Out:
# 0.8131868131868132

# %%
# 非标准化
clf = LogisticRegression().fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8021978021978022

# %% [markdown]
# ## 8.2 KNN 模型

# %%
from sklearn.neighbors import KNeighborsClassifier
# 标准化
clf = KNeighborsClassifier(n_neighbors=3).fit(X_train_scaler, y_train_scaler)
clf.score(X_test_scaler, y_test_scaler)
# Out:
# 0.8571428571428571

# %% [markdown]
# ## 8.3 GaussianNB 模型

# %%
from sklearn.naive_bayes import GaussianNB
# 标准化
clf = GaussianNB().fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8021978021978022

# %% [markdown]
# ## 8.4Tree树模型

# %%
from sklearn.tree import DecisionTreeClassifier
# 标准化
clf = DecisionTreeClassifier().fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.7252747252747253

# %% [markdown]
# ## 8.5 bagging模型

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
# 标准化
clf = BaggingClassifier(KNeighborsClassifier(), max_samples=0.5, max_features=0.5).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.6813186813186813

# %% [markdown]
# ## 8.6 随机森林

# %%
from sklearn.ensemble import RandomForestClassifier
# 标准化
clf = RandomForestClassifier(n_estimators=100, max_depth=None, min_samples_split=2, random_state=0).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8351648351648352

# %% [markdown]
# ## 8.7 ExTree模型

# %%
from sklearn.ensemble import ExtraTreesClassifier
# 标准化
clf = ExtraTreesClassifier(n_estimators=100, max_depth=None, min_samples_split=2, random_state=0).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8131868131868132

# %% [markdown]
# ## 8.8 AdaBoost模型

# %%
from sklearn.ensemble import AdaBoostClassifier
# 标准化
clf = AdaBoostClassifier(n_estimators=100).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.7912087912087912

# %% [markdown]
# ## 8.9 GBDT模型

# %%
from sklearn.ensemble import GradientBoostingClassifier
# 标准化
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8131868131868132

# %% [markdown]
# # 9 模型融合
# ## 9.1 模型投票
# 投票的模型融合需要去除 单模型效果不好的，因为投票模型融合改善的是variance ，对偏差降的低，所以单模型差的会拉低融合模型

# %%
from sklearn import datasets
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.preprocessing import StandardScaler

stdScaler = StandardScaler()
X = stdScaler.fit_transform(df_data[features_name])
y = df_data['target']


clf1 = GaussianNB()
clf2 = DecisionTreeClassifier()
clf3 = KNeighborsClassifier(n_neighbors=3)

eclf = VotingClassifier(estimators=[('lr', clf1), ('tree', clf2), ('knn', clf3)], voting='hard')

for clf, label in zip([clf1, clf2, clf3, eclf], ['GaussianNB', 'DecisionTreeClassifier', 'KNeighborsClassifier', 'Ensemble']):
    scores = cross_val_score(clf, X, y, cv=5, scoring='accuracy')
    print("Accuracy: %0.5f (+/- %0.5f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# Accuracy: 0.80508 (+/- 0.05545) [GaussianNB]
# Accuracy: 0.75885 (+/- 0.04830) [DecisionTreeClassifier]
# Accuracy: 0.82186 (+/- 0.03659) [KNeighborsClassifier]
# Accuracy: 0.82503 (+/- 0.04407) [Ensemble]

# %% [markdown]
# ## lgb 模型

# %%
import lightgbm

X_train, X_test, y_train, y_test = train_test_split(df_data[features_name], df_data['target'], test_size=0.4, random_state=0)
X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, test_size=0.5, random_state=0)

clf = lightgbm

train_matrix = clf.Dataset(X_train, label=y_train)
test_matrix = clf.Dataset(X_test, label=y_test)
params = {
          # 这些参数需要学习
          'boosting_type': 'gbdt',
          #'boosting_type': 'dart',
          'objective': 'multiclass',
          'metric': 'multi_logloss',  # 评测函数，这个比较重要
          'min_child_weight': 1.5,
          'num_leaves': 2**5,
          'lambda_l2': 10,
          'subsample': 0.7,
          'colsample_bytree': 0.7,
          'colsample_bylevel': 0.7,
          'tree_method': 'exact',
          'seed': 2020,
          'learning_rate': 0.01, # 学习率 重要
          'num_class': 2,  # 重要
          'silent': True,
          }
num_round = 400  # 训练的轮数
early_stopping_rounds = 10
model = clf.train(params, 
                  train_matrix,
                  num_round,
                  valid_sets=test_matrix,
                  early_stopping_rounds=early_stopping_rounds)
pre= model.predict(X_valid,num_iteration=model.best_iteration)
# Out:
# [LightGBM] [Warning] Unknown parameter: colsample_bylevel
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: colsample_bylevel
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002596 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 205
# [LightGBM] [Info] Number of data points in the train set: 181, number of used features: 13
# [LightGBM] [Warning] Unknown parameter: colsample_bylevel
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Start training from score -0.829049
# [LightGBM] [Info] Start training from score -0.573524
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's multi_logloss: 0.704815
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's multi_logloss: 0.701917
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's multi_logloss: 0.699176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's multi_logloss: 0.696867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's multi_logloss: 0.69455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's multi_logloss: 0.692036
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's multi_logloss: 0.689463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's multi_logloss: 0.686963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's multi_logloss: 0.684767
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's multi_logloss: 0.682473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's multi_logloss: 0.680277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's multi_logloss: 0.678117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's multi_logloss: 0.67578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's multi_logloss: 0.673659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's multi_logloss: 0.67161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's multi_logloss: 0.669306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's multi_logloss: 0.667655
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's multi_logloss: 0.437509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	valid_0's multi_logloss: 0.437094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	valid_0's multi_logloss: 0.436436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's multi_logloss: 0.436039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	valid_0's multi_logloss: 0.435572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid_0's multi_logloss: 0.435308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	valid_0's multi_logloss: 0.434712
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's multi_logloss: 0.434164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid_0's multi_logloss: 0.433607
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid_0's multi_logloss: 0.433401
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	valid_0's multi_logloss: 0.433172
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's multi_logloss: 0.432683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid_0's multi_logloss: 0.432671
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317]	valid_0's multi_logloss: 0.412741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	valid_0's multi_logloss: 0.412421
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [319]	valid_0's multi_logloss: 0.412282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320]	valid_0's multi_logloss: 0.412273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	valid_0's multi_logloss: 0.41188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	valid_0's multi_logloss: 0.411622
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [323]	valid_0's multi_logloss: 0.411514
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	valid_0's multi_logloss: 0.411241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's multi_logloss: 0.410979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's multi_logloss: 0.411009
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's multi_logloss: 0.410656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328]	valid_0's multi_logloss: 0.410597
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329]	valid_0's multi_logloss: 0.410201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's multi_logloss: 0.410192
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's multi_logloss: 0.409982
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [332]	valid_0's multi_logloss: 0.409819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's multi_logloss: 0.409743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	valid_0's multi_logloss: 0.409646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [335]	valid_0's multi_logloss: 0.409679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [336]	valid_0's multi_logloss: 0.409464
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [337]	valid_0's multi_logloss: 0.40909
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [338]	valid_0's multi_logloss: 0.408853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's multi_logloss: 0.408642
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [340]	valid_0's multi_logloss: 0.408553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [341]	valid_0's multi_logloss: 0.408118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [342]	valid_0's multi_logloss: 0.408226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's multi_logloss: 0.407996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [344]	valid_0's multi_logloss: 0.407862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [345]	valid_0's multi_logloss: 0.407955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346]	valid_0's multi_logloss: 0.407662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's multi_logloss: 0.407487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's multi_logloss: 0.407223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [349]	valid_0's multi_logloss: 0.407235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	valid_0's multi_logloss: 0.407161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351]	valid_0's multi_logloss: 0.407074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's multi_logloss: 0.407024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	valid_0's multi_logloss: 0.406704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	valid_0's multi_logloss: 0.406394
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [355]	valid_0's multi_logloss: 0.406309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [356]	valid_0's multi_logloss: 0.406269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's multi_logloss: 0.406097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	valid_0's multi_logloss: 0.406066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's multi_logloss: 0.406032
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's multi_logloss: 0.405759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [361]	valid_0's multi_logloss: 0.405768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [362]	valid_0's multi_logloss: 0.405877
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [363]	valid_0's multi_logloss: 0.405817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's multi_logloss: 0.4056
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's multi_logloss: 0.405415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	valid_0's multi_logloss: 0.405113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's multi_logloss: 0.405028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's multi_logloss: 0.404757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's multi_logloss: 0.404725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [370]	valid_0's multi_logloss: 0.404667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371]	valid_0's multi_logloss: 0.404637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [372]	valid_0's multi_logloss: 0.404312
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's multi_logloss: 0.404114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's multi_logloss: 0.404094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's multi_logloss: 0.403863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's multi_logloss: 0.403831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's multi_logloss: 0.40363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's multi_logloss: 0.403528
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	valid_0's multi_logloss: 0.403712
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's multi_logloss: 0.403576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [381]	valid_0's multi_logloss: 0.403545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's multi_logloss: 0.403343
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's multi_logloss: 0.403364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's multi_logloss: 0.403365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's multi_logloss: 0.403199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	valid_0's multi_logloss: 0.4031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	valid_0's multi_logloss: 0.402983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's multi_logloss: 0.402778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's multi_logloss: 0.40253
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [390]	valid_0's multi_logloss: 0.402467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [391]	valid_0's multi_logloss: 0.402137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	valid_0's multi_logloss: 0.402285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's multi_logloss: 0.402085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's multi_logloss: 0.402137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [395]	valid_0's multi_logloss: 0.402057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's multi_logloss: 0.402188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's multi_logloss: 0.40219
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	valid_0's multi_logloss: 0.402157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's multi_logloss: 0.402039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's multi_logloss: 0.401969
# Did not meet early stopping. Best iteration is:
# [400]	valid_0's multi_logloss: 0.401969

# %%
print('score : ', np.mean((pre[:,1]>0.5)==y_valid))
# Out:
# score :  0.8032786885245902

# %% [markdown]
# ## xgb 模型

# %%
import xgboost

X_train, X_test, y_train, y_test = train_test_split(df_data[features_name], df_data['target'], test_size=0.4, random_state=0)
X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, test_size=0.5, random_state=0)

clf = xgboost

train_matrix = clf.DMatrix(X_train, label=y_train, missing=-1)
test_matrix = clf.DMatrix(X_test, label=y_test, missing=-1)
z = clf.DMatrix(X_valid, label=y_valid, missing=-1)
params = {'booster': 'gbtree',
          'objective': 'multi:softprob',
          'eval_metric': 'mlogloss',
          'gamma': 1,
          'min_child_weight': 1.5,
          'max_depth': 5,
          'lambda': 10,
          'subsample': 0.7,
          'colsample_bytree': 0.7,
          'colsample_bylevel': 0.7,
          'eta': 0.3,
          'tree_method': 'exact',
          'seed': 2017,
          "num_class": 2
          }

num_round = 200  # 重要
# 通过设置参数 early_stopping_rounds 来解决因为迭代次数过多而过拟合的状态
# 设置early_stopping_rounds=10，当验证loss在10轮迭代之内，都没有提升的话，就stop
early_stopping_rounds = 10 # 重要

watchlist = [(train_matrix, 'train'),
             (test_matrix, 'eval')
             ]

model = clf.train(params,
                  train_matrix,
                  num_boost_round=num_round,
                  evals=watchlist,
                  early_stopping_rounds=early_stopping_rounds
                  )
pre = model.predict(z,ntree_limit=model.best_ntree_limit)
# Out:
# [0]	train-mlogloss:0.61265	eval-mlogloss:0.62632
# [1]	train-mlogloss:0.53984	eval-mlogloss:0.56602
# [2]	train-mlogloss:0.49829	eval-mlogloss:0.54058
# [3]	train-mlogloss:0.46326	eval-mlogloss:0.52277
# [4]	train-mlogloss:0.43378	eval-mlogloss:0.49416
# [5]	train-mlogloss:0.41212	eval-mlogloss:0.48358
# [6]	train-mlogloss:0.39165	eval-mlogloss:0.46807
# [7]	train-mlogloss:0.38168	eval-mlogloss:0.45675
# [8]	train-mlogloss:0.36862	eval-mlogloss:0.44930
# [9]	train-mlogloss:0.36014	eval-mlogloss:0.43464
# [10]	train-mlogloss:0.35018	eval-mlogloss:0.42165
# [11]	train-mlogloss:0.33912	eval-mlogloss:0.41381
# [12]	train-mlogloss:0.32795	eval-mlogloss:0.40592
# [13]	train-mlogloss:0.32252	eval-mlogloss:0.40699
# [14]	train-mlogloss:0.31852	eval-mlogloss:0.40272
# [15]	train-mlogloss:0.30799	eval-mlogloss:0.39976
# [16]	train-mlogloss:0.30600	eval-mlogloss:0.39944
# [17]	train-mlogloss:0.30255	eval-mlogloss:0.39771
# [18]	train-mlogloss:0.29806	eval-mlogloss:0.40085
# [19]	train-mlogloss:0.29514	eval-mlogloss:0.39989
# [20]	train-mlogloss:0.29469	eval-mlogloss:0.39806
# [21]	train-mlogloss:0.29176	eval-mlogloss:0.39698
# [22]	train-mlogloss:0.28998	eval-mlogloss:0.39026
# [23]	train-mlogloss:0.28998	eval-mlogloss:0.38989
# [24]	train-mlogloss:0.28998	eval-mlogloss:0.39049
# [25]	train-mlogloss:0.28657	eval-mlogloss:0.38936
# [26]	train-mlogloss:0.28498	eval-mlogloss:0.38430
# [27]	train-mlogloss:0.28498	eval-mlogloss:0.38464
# [28]	train-mlogloss:0.28259	eval-mlogloss:0.38784
# [29]	train-mlogloss:0.28261	eval-mlogloss:0.38752
# [30]	train-mlogloss:0.27970	eval-mlogloss:0.39204
# [31]	train-mlogloss:0.27587	eval-mlogloss:0.38774
# [32]	train-mlogloss:0.27156	eval-mlogloss:0.38866
# [33]	train-mlogloss:0.27019	eval-mlogloss:0.38850
# [34]	train-mlogloss:0.26847	eval-mlogloss:0.39167
# [35]	train-mlogloss:0.26509	eval-mlogloss:0.39102
# [36]	train-mlogloss:0.26506	eval-mlogloss:0.39169

# %%
print('score : ', np.mean((pre[:,1]>0.5)==y_valid))
# Out:
# score :  0.8360655737704918

# %% [markdown]
# ## Stacking,Bootstrap,Bagging技术实践

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

class SBBTree():
    """
        SBBTree
        Stacking,Bootstap,Bagging
    """
    def __init__(
                    self, 
                    params,
                    stacking_num,
                    bagging_num,
                    bagging_test_size,
                    num_boost_round,
                    early_stopping_rounds
                ):
        """
            Initializes the SBBTree.
            Args:
              params : lgb params.
              stacking_num : k_flod stacking.
              bagging_num : bootstrap num.
              bagging_test_size : bootstrap sample rate.
              num_boost_round : boost num.
              early_stopping_rounds : early_stopping_rounds.
        """
        self.params = params
        self.stacking_num = stacking_num
        self.bagging_num = bagging_num
        self.bagging_test_size = bagging_test_size
        self.num_boost_round = num_boost_round
        self.early_stopping_rounds = early_stopping_rounds

        self.model = lgb
        self.stacking_model = []
        self.bagging_model = []

    def fit(self, X, y):
        """ fit model. """
        if self.stacking_num > 1:
            layer_train = np.zeros((X.shape[0], 2))
            self.SK = StratifiedKFold(n_splits=self.stacking_num, shuffle=True, random_state=1)
            for k,(train_index, test_index) in enumerate(self.SK.split(X, y)):
                X_train = X[train_index]
                y_train = y[train_index]
                X_test = X[test_index]
                y_test = y[test_index]

                lgb_train = lgb.Dataset(X_train, y_train)
                lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

                gbm = lgb.train(self.params,
                            lgb_train,
                            num_boost_round=self.num_boost_round,
                            valid_sets=lgb_eval,
                            early_stopping_rounds=self.early_stopping_rounds)

                self.stacking_model.append(gbm)

                pred_y = gbm.predict(X_test, num_iteration=gbm.best_iteration)
                layer_train[test_index, 1] = pred_y

            X = np.hstack((X, layer_train[:,1].reshape((-1,1)))) 
        else:
            pass
        for bn in range(self.bagging_num):
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=self.bagging_test_size, random_state=bn)

            lgb_train = lgb.Dataset(X_train, y_train)
            lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

            gbm = lgb.train(self.params,
                        lgb_train,
                        num_boost_round=self.num_boost_round,
                        valid_sets=lgb_eval,
                        early_stopping_rounds=self.early_stopping_rounds)

            self.bagging_model.append(gbm)

    def predict(self, X_pred):
        """ predict test data. """
        if self.stacking_num > 1:
            test_pred = np.zeros((X_pred.shape[0], self.stacking_num))
            for sn,gbm in enumerate(self.stacking_model):
                pred = gbm.predict(X_pred, num_iteration=gbm.best_iteration)
                test_pred[:, sn] = pred
            X_pred = np.hstack((X_pred, test_pred.mean(axis=1).reshape((-1,1))))  
        else:
            pass 
        for bn,gbm in enumerate(self.bagging_model):
            pred = gbm.predict(X_pred, num_iteration=gbm.best_iteration)
            if bn == 0:
                pred_out=pred
            else:
                pred_out+=pred
        return pred_out/self.bagging_num

"""
    TEST CODE
"""
from sklearn.datasets import make_classification
from sklearn.datasets import load_breast_cancer
from sklearn.datasets import make_gaussian_quantiles
from sklearn import metrics
from sklearn.metrics import f1_score
# X, y = make_classification(n_samples=1000, n_features=25, n_clusters_per_class=1, n_informative=15, random_state=1)
X, y = make_gaussian_quantiles(mean=None, cov=1.0, n_samples=1000, n_features=50, n_classes=2, shuffle=True, random_state=2)
# data = load_breast_cancer()
# X, y = data.data, data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': 'auc',
        'num_leaves': 9,
        'learning_rate': 0.03,
        'feature_fraction_seed': 2,
        'feature_fraction': 0.9,
        'bagging_fraction': 0.8,
        'bagging_freq': 5,
        'min_data': 20,
        'min_hessian': 1,
        'verbose': -1,
        'silent': 0
        }
# test 1
model = SBBTree(params=params, stacking_num=5, bagging_num=1,  bagging_test_size=0.33, num_boost_round=300, early_stopping_rounds=10)
model.fit(X,y)
X_pred = X[0].reshape((1,-1))
pred=model.predict(X_pred)
print('pred')
print(pred)
print('TEST 1 ok')


# test 1
model = SBBTree(params, stacking_num=5, bagging_num=1, bagging_test_size=0.33, num_boost_round=300, early_stopping_rounds=10)
model.fit(X_train,y_train)
pred1=model.predict(X_test)

# test 2 
model = SBBTree(params, stacking_num=5, bagging_num=3, bagging_test_size=0.33, num_boost_round=300, early_stopping_rounds=10)
model.fit(X_train,y_train)
pred2=model.predict(X_test)

# test 3 
model = SBBTree(params, stacking_num=5, bagging_num=1, bagging_test_size=0.33, num_boost_round=300, early_stopping_rounds=10)
model.fit(X_train,y_train)
pred3=model.predict(X_test)

# test 4 
model = SBBTree(params, stacking_num=5, bagging_num=3, bagging_test_size=0.33, num_boost_round=300, early_stopping_rounds=10)
model.fit(X_train,y_train)
pred4=model.predict(X_test)

fpr, tpr, thresholds = metrics.roc_curve(y_test+1, pred1, pos_label=2)
print('auc: ',metrics.auc(fpr, tpr))

fpr, tpr, thresholds = metrics.roc_curve(y_test+1, pred2, pos_label=2)
print('auc: ',metrics.auc(fpr, tpr))

fpr, tpr, thresholds = metrics.roc_curve(y_test+1, pred3, pos_label=2)
print('auc: ',metrics.auc(fpr, tpr))

fpr, tpr, thresholds = metrics.roc_curve(y_test+1, pred4, pos_label=2)
print('auc: ',metrics.auc(fpr, tpr))
# Out:
# [LightGBM] [Warning] Unknown parameter: silent
# [1]	valid_0's auc: 0.52025
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's auc: 0.52855
# [3]	valid_0's auc: 0.5389
# [4]	valid_0's auc: 0.54095
# [5]	valid_0's auc: 0.5319
# [6]	valid_0's auc: 0.54735
# [7]	valid_0's auc: 0.54035
# [8]	valid_0's auc: 0.541
# [9]	valid_0's auc: 0.5389
# [10]	valid_0's auc: 0.54295
# [11]	valid_0's auc: 0.55225
# [12]	valid_0's auc: 0.56285
# [13]	valid_0's auc: 0.57005
# [14]	valid_0's auc: 0.56905
# [15]	valid_0's auc: 0.57955
# [16]	valid_0's auc: 0.58985
# [17]	valid_0's auc: 0.59585
# [18]	valid_0's auc: 0.60575
# [19]	valid_0's auc: 0.60965
# [20]	valid_0's auc: 0.61125
# [21]	valid_0's auc: 0.61065
# [22]	valid_0's auc: 0.61385
# [23]	valid_0's auc: 0.6174
# [24]	valid_0's auc: 0.6222
# [25]	valid_0's auc: 0.6275
# [26]	valid_0's auc: 0.6281
# [27]	valid_0's auc: 0.6287
# [28]	valid_0's auc: 0.6265
# [29]	valid_0's auc: 0.6282
# [30]	valid_0's auc: 0.629
# [31]	valid_0's auc: 0.6309
# [32]	valid_0's auc: 0.6329
# [33]	valid_0's auc: 0.6324
# [34]	valid_0's auc: 0.6335
# [35]	valid_0's auc: 0.6372
# [36]	valid_0's auc: 0.6379
# [37]	valid_0's auc: 0.6408
# [38]	valid_0's auc: 0.6435
# [39]	valid_0's auc: 0.6494
# [40]	valid_0's auc: 0.6531
# [41]	valid_0's auc: 0.6621
# [42]	valid_0's auc: 0.6602
# [43]	valid_0's auc: 0.6639
# [44]	valid_0's auc: 0.6666
# [45]	valid_0's auc: 0.6684
# [46]	valid_0's auc: 0.6672
# [47]	valid_0's auc: 0.6688
# [48]	valid_0's auc: 0.6689
# [49]	valid_0's auc: 0.666
# [50]	valid_0's auc: 0.6656
# [51]	valid_0's auc: 0.6617
# [52]	valid_0's auc: 0.6673
# [53]	valid_0's auc: 0.6701
# [54]	valid_0's auc: 0.6743
# [55]	valid_0's auc: 0.6762
# [56]	valid_0's auc: 0.6768
# [57]	valid_0's auc: 0.6777
# [58]	valid_0's auc: 0.6806
# Early stopping, best iteration is:
# [2]	valid_0's auc: 0.649225
# auc:  0.6331604693074404
# auc:  0.6424657030416713
# auc:  0.6331604693074404
# auc:  0.6424657030416713

# %% [markdown]
# ## 实战

# %%
params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': 'auc',
        'num_leaves': 9,
        'learning_rate': 0.33, # 0.3  、 0.01
        'feature_fraction_seed': 2,
        'feature_fraction': 0.9,
        'bagging_fraction': 0.8,
        'bagging_freq': 5,
        'min_data': 20,
        'min_hessian': 1,
        'verbose': -1,
        'silent': 0
        }

model = SBBTree(params=params,
                stacking_num=5,
                bagging_num=3,
                bagging_test_size=0.33,
                num_boost_round=200,
                early_stopping_rounds=20)

X_train, X_test, y_train, y_test = train_test_split(df_data[features_name], df_data['target'], test_size=0.4, random_state=0)

model.fit(X_train.values, y_train.values)
pred = model.predict(X_test.values)
print('score : ', np.mean((pred>0.5)==y_test))
# Out:
# [LightGBM] [Warning] Unknown parameter: silent
# [1]	valid_0's auc: 0.797619
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's auc: 0.875
# [3]	valid_0's auc: 0.861607
# [4]	valid_0's auc: 0.872024
# [5]	valid_0's auc: 0.889881
# [6]	valid_0's auc: 0.88244
# [7]	valid_0's auc: 0.876488
# [8]	valid_0's auc: 0.875
# [9]	valid_0's auc: 0.877976
# [10]	valid_0's auc: 0.883929
# [11]	valid_0's auc: 0.901786
# [12]	valid_0's auc: 0.889881
# [13]	valid_0's auc: 0.89881
# [14]	valid_0's auc: 0.892857
# [15]	valid_0's auc: 0.889881
# [16]	valid_0's auc: 0.886905
# [17]	valid_0's auc: 0.886905
# [18]	valid_0's auc: 0.892857
# [19]	valid_0's auc: 0.880952
# [20]	valid_0's auc: 0.886905
# [21]	valid_0's auc: 0.877976
# [22]	valid_0's auc: 0.877976
# [23]	valid_0's auc: 0.875
# [24]	valid_0's auc: 0.866071
# [25]	valid_0's auc: 0.863095
# [26]	valid_0's auc: 0.860119
# [27]	valid_0's auc: 0.866071
# [28]	valid_0's auc: 0.880952
# [29]	valid_0's auc: 0.886905
# [30]	valid_0's auc: 0.892857
# [31]	valid_0's auc: 0.883929
# Early stopping, best iteration is:
# [11]	valid_0's auc: 0.901786
# [LightGBM] [Warning] Unknown parameter: silent
# [1]	valid_0's auc: 0.702381
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's auc: 0.693452
# [3]	valid_0's auc: 0.74256
# [4]	valid_0's auc: 0.752976
# [5]	valid_0's auc: 0.818452
# [6]	valid_0's auc: 0.8125
# [7]	valid_0's auc: 0.8125
# [8]	valid_0's auc: 0.794643
# [9]	valid_0's auc: 0.809524
# [10]	valid_0's auc: 0.800595
# [11]	valid_0's auc: 0.803571
# [12]	valid_0's auc: 0.824405
# [13]	valid_0's auc: 0.83631
# [14]	valid_0's auc: 0.830357
# [15]	valid_0's auc: 0.833333
# [16]	valid_0's auc: 0.842262
# [17]	valid_0's auc: 0.839286
# [18]	valid_0's auc: 0.833333
# [19]	valid_0's auc: 0.821429
# [20]	valid_0's auc: 0.845238
# [21]	valid_0's auc: 0.848214
# [22]	valid_0's auc: 0.854167
# [23]	valid_0's auc: 0.848214
# [24]	valid_0's auc: 0.854167
# [25]	valid_0's auc: 0.860119
# [26]	valid_0's auc: 0.866071
# [27]	valid_0's auc: 0.866071
# [28]	valid_0's auc: 0.854167
# [29]	valid_0's auc: 0.866071
# [30]	valid_0's auc: 0.854167
# [31]	valid_0's auc: 0.863095
# [32]	valid_0's auc: 0.866071
# [33]	valid_0's auc: 0.869048
# [34]	valid_0's auc: 0.863095
# [35]	valid_0's auc: 0.857143
# [36]	valid_0's auc: 0.866071
# [37]	valid_0's auc: 0.85119
# [38]	valid_0's auc: 0.854167
